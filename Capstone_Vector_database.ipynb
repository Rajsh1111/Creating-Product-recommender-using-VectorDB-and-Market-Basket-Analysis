# %% [markdown]
# # LOADING THE LIBRARIES

# %%
# !pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-0.4.24-py3-none-any.whl (525 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.5/525.5 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.0.3)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.6.3)
# Collecting chroma-hnswlib==0.7.3 (from chromadb)
#   Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 12.0 MB/s eta 0:00:00
# Collecting fastapi>=0.95.2 (from chromadb)
#   Downloading fastapi-0.110.0-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 11.5 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3 (from chromadb)
#   Downloading uvicorn-0.27.1-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.25.2)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.5.0-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.10.0)
# Collecting pulsar-client>=3.1.0 (from chromadb)
#   Downloading pulsar_client-3.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 20.7 MB/s eta 0:00:00
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.17.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 35.3 MB/s eta 0:00:00
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.23.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 8.5 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.23.0-py3-none-any.whl (18 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.44b0-py3-none-any.whl (11 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.23.0-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.15.2)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 9.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.66.2)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.1.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.62.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.1.2-cp39-abi3-manylinux_2_28_x86_64.whl (698 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.9/698.9 kB 40.4 MB/s eta 0:00:00
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.9.0)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 26.9 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.0.1)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 8.4 MB/s eta 0:00:00
# Collecting orjson>=3.9.12 (from chromadb)
#   Downloading orjson-3.9.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (1.0.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (2.0.1)
# Collecting starlette<0.37.0,>=0.36.3 (from fastapi>=0.95.2->chromadb)
#   Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.0.7)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting importlib-metadata<7.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.62.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.23.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.23.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-proto==1.23.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.23.0-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 6.9 MB/s eta 0:00:00
# Collecting opentelemetry-instrumentation-asgi==0.44b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.44b0-py3-none-any.whl (14 kB)
# Collecting opentelemetry-instrumentation==0.44b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.44b0-py3-none-any.whl (28 kB)
# Collecting opentelemetry-semantic-conventions==0.44b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.44b0-py3-none-any.whl (36 kB)
# Collecting opentelemetry-util-http==0.44b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.44b0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (67.7.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading asgiref-3.7.2-py3-none-any.whl (24 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.6)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.2->chromadb) (0.20.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting h11>=0.8 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.6 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 19.7 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 30.2 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 47.7 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2023.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.37.0,>=0.36.3->fastapi>=0.95.2->chromadb) (3.7.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.37.0,>=0.36.3->fastapi>=0.95.2->chromadb) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.37.0,>=0.36.3->fastapi>=0.95.2->chromadb) (1.2.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.5.1)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=5e345c7a1c2ebab5a291646bee7165cf4ae3c8e6f5c3c8a489e7ea91810d5d80
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, monotonic, mmh3, websockets, uvloop, python-dotenv, pulsar-client, overrides, orjson, opentelemetry-util-http, opentelemetry-semantic-conventions, opentelemetry-proto, importlib-metadata, humanfriendly, httptools, h11, deprecated, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, uvicorn, starlette, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, coloredlogs, opentelemetry-sdk, opentelemetry-instrumentation, onnxruntime, kubernetes, fastapi, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 7.0.1
#     Uninstalling importlib-metadata-7.0.1:
#       Successfully uninstalled importlib-metadata-7.0.1
# Successfully installed asgiref-3.7.2 backoff-2.2.1 bcrypt-4.1.2 chroma-hnswlib-0.7.3 chromadb-0.4.24 coloredlogs-15.0.1 deprecated-1.2.14 fastapi-0.110.0 h11-0.14.0 httptools-0.6.1 humanfriendly-10.0 importlib-metadata-6.11.0 kubernetes-29.0.0 mmh3-4.1.0 monotonic-1.6 onnxruntime-1.17.1 opentelemetry-api-1.23.0 opentelemetry-exporter-otlp-proto-common-1.23.0 opentelemetry-exporter-otlp-proto-grpc-1.23.0 opentelemetry-instrumentation-0.44b0 opentelemetry-instrumentation-asgi-0.44b0 opentelemetry-instrumentation-fastapi-0.44b0 opentelemetry-proto-1.23.0 opentelemetry-sdk-1.23.0 opentelemetry-semantic-conventions-0.44b0 opentelemetry-util-http-0.44b0 orjson-3.9.15 overrides-7.7.0 posthog-3.5.0 pulsar-client-3.4.0 pypika-0.48.9 python-dotenv-1.0.1 starlette-0.36.3 uvicorn-0.27.1 uvloop-0.19.0 watchfiles-0.21.0 websockets-12.0

# %%
# !pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Downloading sentence_transformers-2.5.1-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.38.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.1.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence_transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence_transformers) (0.4.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.3.0)
# Installing collected packages: sentence_transformers
# Successfully installed sentence_transformers-2.5.1

# %%
import chromadb

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Out:
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
downloaded = drive.CreateFile({'id':'1knKLc16AwF39X1RMq0v92dzN008l--pH'})#replace withid in your google drive for product codes file
downloaded.GetContentFile('Product code.csv')
#https://drive.google.com/file/d/192Wh5hV6Dwz5QcF14q7ItZ97PfcFAoih/view?usp=drive_link

# %% [markdown]
# # LOADING THE DATA

# %% [markdown]
# Column Descriptors
# - StockCode: A code used to identify the product that was purchased
# - Description: A brief description of the product that was purchased
# - Details: Detailed description of the purchased product

# %%
import csv

# Load Product Code data
with open('Product code.csv') as file:
    lines = csv.reader(file)

    # Store the name of the menu items in this array. In Chroma, a "document" is a string i.e. name, sentence, paragraph, etc.
    documents = []

    # Store the corresponding menu item IDs in this array.
    metadatas = []

    # Each "document" needs a unique ID. This is like the primary key of a relational database. We'll start at 1 and increment from there.
    ids = []
    id = 1

    # Loop thru each line and populate the 3 arrays.
    for i, line in enumerate(lines):
        if i==0:
            # Skip the first row (the column headers)
            continue

        documents.append(line[1])
        metadatas.append({"item_id": line[0]})
        ids.append(str(id))
        id+=1

# %%
len(metadatas)
# Out:
# 3839

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Instantiate the Chroma client
#
#
#
#
#
# Create collection for embeddings
#
# Query collection

# %%
from chromadb.utils import embedding_functions

# Instantiate chromadb instance. Data is stored in memory only.
# chroma_client = chromadb.Client()

# Instantiate chromadb instance. Data is stored on disk (a folder named 'my_vectordb' will be created in the same folder as this file).
chroma_client = chromadb.PersistentClient(path="/content/drive/My Drive/Colab Notebooks/")

# %%
sentence_transformer_ef = embedding_functions.SentenceTransformerEmbeddingFunction(model_name="all-mpnet-base-v2")

# Use this to delete the database
# chroma_client.delete_collection(name="my_collection")

# Create the collection, aka vector database. Or, if database already exist, then use it. Specify the model that we want to use to do the embedding.
collection = chroma_client.get_or_create_collection(name="my_collection", embedding_function=sentence_transformer_ef)

# %%
# Add all the data to the vector database. ChromaDB automatically converts and stores the text as vector embeddings. This may take a few minutes.
collection.add(
    documents=documents,
    metadatas=metadatas,
    ids=ids
)
# Out:
# Streaming output truncated to the last 5000 lines.
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2679
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2680
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2681
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2682
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2683
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2684
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2685
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2686
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2687
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2688
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2689
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2690
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2691
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2692
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2693
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2694
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2695
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2696
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2697
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2698
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2699
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2700
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2701
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2702
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2703
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2704
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2705
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2706
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2707
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2708
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2709
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2710
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2711
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2712
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2713
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2714
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2715
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2716
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2717
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2718
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2719
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2720
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2721
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2722
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2723
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2724
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2725
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2726
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2727
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2728
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2729
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2730
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2731
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2732
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2733
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2734
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2735
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2736
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2737
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2738
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2739
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2740
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2741
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2742
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2743
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2744
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2745
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2746
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2747
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2748
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2749
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2750
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2751
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2752
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2753
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2754
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2755
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2756
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2757
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2758
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2759
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2760
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2761
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2762
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2763
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2764
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2765
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2766
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2767
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2768
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2769
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2770
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2771
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2772
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2773
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2774
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2775
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2776
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2777
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2778
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2779
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2780
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2781
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2782
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2783
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2784
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2785
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2786
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2787
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2788
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2789
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2790
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2791
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2792
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2793
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2794
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2795
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2796
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2797
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2798
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2799
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2800
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2801
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2802
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2803
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2804
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2805
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2806
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2807
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2808
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2809
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2810
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2811
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2812
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2813
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2814
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2815
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2816
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2817
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2818
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2819
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2820
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2821
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2822
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2823
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2824
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2825
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2826
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2827
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2828
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2829
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2830
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2831
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2832
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2833
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2834
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2835
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2836
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2837
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2838
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2839
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2840
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2841
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2842
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2843
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2844
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2845
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2846
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2847
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2848
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2849
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2850
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2851
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2852
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2853
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2854
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2855
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2856
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2857
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2858
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2859
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2860
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2861
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2862
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2863
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2864
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2865
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2866
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2867
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2868
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2869
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2870
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2871
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2872
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2873
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2874
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2875
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2876
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2877
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2878
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2879
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2880
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2881
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2882
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2883
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2884
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2885
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2886
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2887
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2888
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2889
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2890
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2891
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2892
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2893
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2894
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2895
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2896
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2897
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2898
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2899
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2900
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2901
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2902
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2903
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2904
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2905
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2906
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2907
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2908
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2909
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2910
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2911
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2912
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2913
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2914
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2915
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2916
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2917
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2918
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2919
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2920
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2921
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2922
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2923
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2924
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2925
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2926
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2927
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2928
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2929
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2930
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2931
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2932
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2933
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2934
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2935
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2936
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2937
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2938
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2939
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2940
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2941
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2942
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2943
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2944
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2945
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2946
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2947
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2948
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2949
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2950
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2951
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2952
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2953
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2954
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2955
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2956
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2957
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2958
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2959
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2960
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2961
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2962
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2963
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2964
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2965
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2966
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2967
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2968
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2969
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2970
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2971
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2972
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2973
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2974
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2975
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2976
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2977
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2978
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2979
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2980
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2981
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2982
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2983
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2984
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2985
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2986
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2987
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2988
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2989
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2990
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2991
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2992
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2993
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2994
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2995
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2996
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2997
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2998
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 2999
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3000
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3001
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3002
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3003
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3004
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3005
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3006
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3007
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3008
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3009
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3010
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3011
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3012
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3013
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3014
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3015
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3016
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3017
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3018
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3019
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3020
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3021
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3022
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3023
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3024
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3025
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3026
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3027
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3028
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3029
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3030
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3031
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3032
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3033
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3034
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3035
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3036
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3037
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3038
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3039
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3040
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3041
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3042
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3043
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3044
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3045
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3046
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3047
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3048
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3049
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3050
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3051
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3052
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3053
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3054
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3055
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3056
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3057
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3058
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3059
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3060
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3061
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3062
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3063
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3064
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3065
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3066
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3067
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3068
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3069
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3070
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3071
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3072
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3073
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3074
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3075
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3076
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3077
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3078
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3079
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3080
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3081
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3082
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3083
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3084
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3085
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3086
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3087
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3088
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3089
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3090
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3091
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3092
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3093
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3094
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3095
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3096
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3097
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3098
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3099
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3100
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3101
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3102
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3103
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3104
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3105
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3106
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3107
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3108
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3109
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3110
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3111
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3112
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3113
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3114
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3115
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3116
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3117
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3118
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3119
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3120
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3121
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3122
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3123
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3124
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3125
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3126
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3127
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3128
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3129
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3130
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3131
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3132
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3133
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3134
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3135
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3136
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3137
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3138
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3139
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3140
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3141
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3142
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3143
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3144
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3145
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3146
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3147
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3148
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3149
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3150
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3151
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3152
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3153
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3154
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3155
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3156
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3157
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3158
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3159
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3160
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3161
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3162
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3163
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3164
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3165
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3166
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3167
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3168
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3169
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3170
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3171
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3172
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3173
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3174
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3175
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3176
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3177
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3178
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3179
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3180
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3181
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3182
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3183
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3184
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3185
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3186
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3187
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3188
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3189
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3190
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3191
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3192
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3193
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3194
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3195
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3196
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3197
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3198
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3199
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3200
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3201
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3202
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3203
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3204
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3205
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3206
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3207
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3208
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3209
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3210
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3211
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3212
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3213
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3214
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3215
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3216
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3217
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3218
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3219
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3220
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3221
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3222
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3223
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3224
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3225
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3226
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3227
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3228
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3229
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3230
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3231
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3232
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3233
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3234
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3235
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3236
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3237
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3238
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3239
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3240
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3241
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3242
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3243
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3244
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3245
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3246
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3247
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: 3248
# ...
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3670
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3671
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3672
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3673
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3674
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3675
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3676
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3677
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3678
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3679
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3680
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3681
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3682
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3683
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3684
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3685
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3686
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3687
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3688
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3689
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3690
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3691
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3692
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3693
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3694
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3695
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3696
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3697
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3698
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3699
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3700
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3701
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3702
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3703
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3704
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3705
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3706
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3707
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3708
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3709
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3710
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3711
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3712
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3713
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3714
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3715
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3716
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3717
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3718
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3719
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3720
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3721
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3722
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3723
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3724
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3725
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3726
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3727
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3728
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3729
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3730
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3731
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3732
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3733
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3734
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3735
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3736
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3737
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3738
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3739
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3740
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3741
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3742
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3743
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3744
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3745
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3746
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3747
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3748
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3749
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3750
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3751
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3752
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3753
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3754
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3755
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3756
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3757
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3758
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3759
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3760
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3761
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3762
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3763
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3764
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3765
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3766
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3767
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3768
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3769
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3770
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3771
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3772
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3773
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3774
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3775
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3776
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3777
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3778
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3779
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3780
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3781
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3782
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3783
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3784
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3785
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3786
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3787
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3788
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3789
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3790
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3791
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3792
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3793
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3794
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3795
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3796
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3797
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3798
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3799
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3800
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3801
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3802
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3803
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3804
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3805
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3806
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3807
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3808
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3809
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3810
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3811
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3812
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3813
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3814
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3815
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3816
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3817
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3818
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3819
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3820
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3821
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3822
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3823
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3824
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3825
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3826
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3827
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3828
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3829
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3830
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3831
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3832
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3833
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3834
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3835
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3836
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3837
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3838
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3839

# %% [markdown]
# # Query the vector database

# %%
# Query mispelled word: 'PATRY BUKNING'. Expect to find the correctly spelled  items
results = collection.query(
    query_texts=["PATRY BUKNING"],
    n_results=5,
    include=['documents', 'distances', 'metadatas']
)
print(results['documents'])
print(results['distances'])
print(results['metadatas'])
# Out:
# [['RED BABY BUNTING ', 'PARTY BUNTING', 'SPOTTY BUNTING', 'PINK BABY BUNTING', 'ALARM CLOCK BAKELIKE CHOCOLATE']]
# [[1.31281578540802, 1.3319528102874756, 1.3514946699142456, 1.3577312231063843, 1.3757050037384033]]
# [[{'item_id': '22669'}, {'item_id': '47566'}, {'item_id': '23298'}, {'item_id': '22668'}, {'item_id': '22725'}]]

# %%
# Query mispelled word: 'PATRY BUKNING'. Expect to find the correctly spelled  items

results = collection.query(
    query_texts=["PATRY BUKNING"],
    n_results=10,
    include=['documents', 'distances', 'metadatas']
)
print(results['documents'])
print(results['distances'])
print(results['metadatas'])
# Out:
# [['RED BABY BUNTING ', 'PARTY BUNTING', 'SPOTTY BUNTING', 'PINK BABY BUNTING', 'ALARM CLOCK BAKELIKE CHOCOLATE', 'ALARM CLOCK BAKELIKE IVORY', 'PAPER BUNTING PAISLEY PARK', 'CANDY SPOT BUNNY', 'ALARM CLOCK BAKELIKE ORANGE', 'PIN CUSHION BABUSHKA RED']]
# [[1.31281578540802, 1.3319528102874756, 1.3514946699142456, 1.3577312231063843, 1.3757050037384033, 1.38956618309021, 1.392085375508959, 1.3989320993423462, 1.4158439636230469, 1.4181098937988281]]
# [[{'item_id': '22669'}, {'item_id': '47566'}, {'item_id': '23298'}, {'item_id': '22668'}, {'item_id': '22725'}, {'item_id': '22730'}, {'item_id': '23597'}, {'item_id': '85089'}, {'item_id': '22729'}, {'item_id': '22448'}]]

# %%
# Query word variation: 'REGNCY CAKESTND 3 TIER'. Expect to find the 'REGENCY CAKESTAND 3 TIER' item

results = collection.query(
    query_texts=["REGNCY CAKESTND 3 TIER"],
    n_results=5,
    include=['documents', 'distances', 'metadatas']
)
print(results['documents'])
print(results['distances'])
print(results['metadatas'])
# Out:
# [['REGENCY CAKESTAND 3 TIER', 'SWEETHEART CAKESTAND 3 TIER', '3 TIER CAKE TIN RED AND CREAM', '3 TIER CAKE TIN GREEN AND CREAM', 'CAKE STAND 3 TIER MAGIC GARDEN']]
# [[0.5575416684150696, 0.6835066080093384, 0.8116592168807983, 0.8361910581588745, 0.8596285581588745]]
# [[{'item_id': '22423'}, {'item_id': '22776'}, {'item_id': '22838'}, {'item_id': '22839'}, {'item_id': '22236'}]]

# %%
# Query word variation: 'REGNCY CAKESTND 3 TIER'. Expect to find the 'REGENCY CAKESTAND 3 TIER' item

results = collection.query(
    query_texts=["REGNCY CAKESTND 3 TIER"],
    n_results=10,
    include=['documents', 'distances', 'metadatas']
)
print(results['documents'])
print(results['distances'])
print(results['metadatas'])
# Out:
# [['REGENCY CAKESTAND 3 TIER', 'SWEETHEART CAKESTAND 3 TIER', '3 TIER CAKE TIN RED AND CREAM', '3 TIER CAKE TIN GREEN AND CREAM', 'CAKE STAND 3 TIER MAGIC GARDEN', 'NOVELTY BISCUITS CAKE STAND 3 TIER', 'CAKE STAND LOVEBIRD 2 TIER WHITE', 'CAKE STAND LOVEBIRD 2 TIER PINK', 'CAKE STAND WHITE TWO TIER LACE', 'REGENCY CAKE SLICE']]
# [[0.5575416684150696, 0.6835066080093384, 0.8116592168807983, 0.8361910581588745, 0.8596285581588745, 0.9351198673248291, 1.0401690006256104, 1.0519944429397583, 1.0538241863250732, 1.1033684015274048]]
# [[{'item_id': '22423'}, {'item_id': '22776'}, {'item_id': '22838'}, {'item_id': '22839'}, {'item_id': '22236'}, {'item_id': '22890'}, {'item_id': '22220'}, {'item_id': '22221'}, {'item_id': '22215'}, {'item_id': '23164'}]]

# %%
# Query similar meaning: 'WHITE HANGING HEART'. Expect to find the 'SIMILAR' items

results = collection.query(
    query_texts=["WHITE HANGING HEART"],
    n_results=5,
    include=['documents', 'distances', 'metadatas']
)
print(results['documents'])
print(results['distances'])
print(results['metadatas'])
# Out:
# [['HANGING HEART BONHEUR', 'PLACE SETTING WHITE HEART', 'YELLOW FELT HANGING HEART W FLOWER', 'BLUE FELT HANGING HEART W FLOWER', 'CANDLEHOLDER PINK HANGING HEART']]
# [[0.6221920251846313, 0.6616895198822021, 0.6793512105941772, 0.699192225933075, 0.7164210081100464]]
# [[{'item_id': '23398'}, {'item_id': '22151'}, {'item_id': '35916A'}, {'item_id': '35916B'}, {'item_id': '22804'}]]

# %%
results = collection.query(
    query_texts=["WHITE HANGING HEART"],
    n_results=10,
    include=['documents', 'distances', 'metadatas']
)
print(results['documents'])
print(results['distances'])
print(results['metadatas'])
# Out:
# [['HANGING HEART BONHEUR', 'PLACE SETTING WHITE HEART', 'YELLOW FELT HANGING HEART W FLOWER', 'BLUE FELT HANGING HEART W FLOWER', 'CANDLEHOLDER PINK HANGING HEART', 'PINK FELT HANGING HEART W FLOWER', 'BLACK HEART CARD HOLDER', 'IVORY HANGING DECORATION  HEART', 'ENGLISH ROSE SCENTED HANGING HEART', 'YELLOW METAL CHICKEN HEART ']]
# [[0.6221920251846313, 0.6616895198822021, 0.6793512105941772, 0.699192225933075, 0.7164210081100464, 0.71767258644104, 0.7392807602882385, 0.7560070753097534, 0.7591907978057861, 0.7709988951683044]]
# [[{'item_id': '23398'}, {'item_id': '22151'}, {'item_id': '35916A'}, {'item_id': '35916B'}, {'item_id': '22804'}, {'item_id': '35916C'}, {'item_id': '22188'}, {'item_id': '21385'}, {'item_id': '47574B'}, {'item_id': '84459B'}]]

# %%
results = collection.query(
    query_texts=["I am looking for a door mat"],
    n_results=15,
    include=['documents', 'distances', 'metadatas']
)
print(results['documents'])
print(results['distances'])
print(results['metadatas'])
# Out:
# [['DOORMAT VINTAGE LEAVES DESIGN ', 'DOORMAT MULTICOLOUR STRIPE', 'DOORMAT NEW ENGLAND', 'RECYCLED ACAPULCO MAT BLUE', 'RECYCLED ACAPULCO MAT PINK', 'RECYCLED ACAPULCO MAT RED', 'RECYCLED ACAPULCO MAT GREEN', 'BLACK ENCHANTED FOREST PLACEMAT', 'DOORMAT WELCOME TO OUR HOME', 'KNEELING MAT HOUSEWORK  DESIGN', 'DOORMAT TOPIARY', 'SQUARE FLOOR CUSHION VINTAGE RED', 'RECYCLED ACAPULCO MAT TURQUOISE', 'RECYCLED ACAPULCO MAT LAVENDER', 'DOORMAT WELCOME PUPPIES']]
# [[1.0683703422546387, 1.075612187385559, 1.0783156156539917, 1.0889254808425903, 1.090099573135376, 1.1124440431594849, 1.1128441095352173, 1.1211400032043457, 1.1349525451660156, 1.1440937519073486, 1.1624468564987183, 1.1683390140533447, 1.171748161315918, 1.1723747253417969, 1.175325870513916]]
# [[{'item_id': '23283'}, {'item_id': '48116'}, {'item_id': '48187'}, {'item_id': '23051'}, {'item_id': '23053'}, {'item_id': '23049'}, {'item_id': '23050'}, {'item_id': '85114A'}, {'item_id': '22692'}, {'item_id': '23302'}, {'item_id': '48129'}, {'item_id': '21629'}, {'item_id': '23052'}, {'item_id': '23054'}, {'item_id': '48188'}]]

# %%
results = collection.query(
    query_texts=["Pls suggest a hand warmer"],
    n_results=15,
    include=['documents', 'distances', 'metadatas']
)
print(results['documents'])
print(results['distances'])
print(results['metadatas'])
# Out:
# [['HI TEC ALPINE HAND WARMER', 'HAND WARMER BABUSHKA DESIGN', 'LOVE HEART POCKET WARMER', 'HAND WARMER RED POLKA DOT', 'HOT WATER BOTTLE I AM SO POORLY', 'HAND WARMER UNION JACK', 'HAND WARMER SCOTTY DOG DESIGN', 'HAND WARMER RED LOVE HEART', 'TEA TIME OVEN GLOVE', 'HAND WARMER BIRD DESIGN', 'HAND WARMER OWL DESIGN', 'HOT WATER BOTTLE KEEP CALM', 'HOT WATER BOTTLE TEA AND SYMPATHY', 'HOT STUFF HOT WATER BOTTLE', 'HOT WATER BOTTLE BABUSHKA ']]
# [[0.7037321329116821, 0.8033459186553955, 0.9284428954124451, 0.937609076499939, 0.9381437301635742, 0.9641802310943604, 0.9826898574829102, 0.9888186454772949, 1.0015605688095093, 1.014425277709961, 1.018113374710083, 1.0559507608413696, 1.0649542808532715, 1.0894415378570557, 1.0988456010818481]]
# [[{'item_id': '70007'}, {'item_id': '22834'}, {'item_id': '70006'}, {'item_id': '22632'}, {'item_id': '22835'}, {'item_id': '22633'}, {'item_id': '22866'}, {'item_id': '23439'}, {'item_id': '47559B'}, {'item_id': '22867'}, {'item_id': '22865'}, {'item_id': '23355'}, {'item_id': '22114'}, {'item_id': '23358'}, {'item_id': '22837'}]]

# %%
results = collection.query(
    query_texts=["I want a cosmetic bag"],
    n_results=15,
    include=['documents', 'distances', 'metadatas']
)
print(results['documents'])
print(results['distances'])
print(results['metadatas'])
# Out:
# [['PINK GREEN EMBROIDERY COSMETIC BAG', 'BLUE GREEN EMBROIDERY COSMETIC BAG', 'GOLD COSMETIC BAG PINK STAR', 'GIRLS PARTY BAG', 'GOLD COSMETICS BAG WITH BUTTERFLY', 'COSMETIC BAG VINTAGE ROSE PAISLEY', 'RED RETROSPOT SHOPPING BAG', 'VINTAGE BEAD COSMETIC BAG ', 'LARGE STRIPES CHOCOLATE GIFT BAG', 'PARTY FOOD SHOPPER BAG', 'RED RETROSPOT SHOPPER BAG', 'ROSE DU SUD COSMETICS BAG', 'TROPICAL HOLIDAY PURSE ', 'SMALL STRIPES CHOCOLATE GIFT BAG ', 'BOYS PARTY BAG']]
# [[0.6450399160385132, 0.6657259464263916, 0.6777951717376709, 0.7088884711265564, 0.7406556606292725, 0.757064163684845, 0.7732295989990234, 0.7738257646560669, 0.7830039858818054, 0.7876776456832886, 0.7895126342773438, 0.7935220003128052, 0.8047601580619812, 0.8083751201629639, 0.8165217638015747]]
# [[{'item_id': '47369A'}, {'item_id': '47369B'}, {'item_id': '20861'}, {'item_id': 'DCGSSGIRL'}, {'item_id': '20860'}, {'item_id': '22277'}, {'item_id': '21039'}, {'item_id': '35649'}, {'item_id': '21289'}, {'item_id': '20716'}, {'item_id': '20718'}, {'item_id': '21000'}, {'item_id': '20664'}, {'item_id': '21292'}, {'item_id': 'DCGSSBOY'}]]

# %%
results = collection.query(
    query_texts=["I want a cosmetic bag"],
    n_results=3,
    include=['documents', 'distances', 'metadatas']
)
print(results['documents'])
print(results['distances'])
print(results['metadatas'])
# Out:
# [['PINK GREEN EMBROIDERY COSMETIC BAG', 'BLUE GREEN EMBROIDERY COSMETIC BAG', 'GOLD COSMETIC BAG PINK STAR']]
# [[0.6450399160385132, 0.6657259464263916, 0.6777951717376709]]
# [[{'item_id': '47369A'}, {'item_id': '47369B'}, {'item_id': '20861'}]]

# %%
import pandas as pd

# %%
data1=pd.read_csv('Product code.csv')

# %%
data1.head(1)
# Out:
#   StockCode                         Description  \
# 0    85123A  WHITE HANGING HEART T-LIGHT HOLDER
#
#                                              Details
# 0  The White Hanging Heart T-Light Holder is a ch...

# %%
data2 = data1.Description.tolist()

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn.functional as F

#Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)


# Sentences we want sentence embeddings for
sentences = data2

# Load model from HuggingFace Hub
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-mpnet-base-v2')
model = AutoModel.from_pretrained('sentence-transformers/all-mpnet-base-v2')

# Tokenize sentences
encoded_input = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt')

# Compute token embeddings
with torch.no_grad():
    model_output = model(**encoded_input)

# Perform pooling
sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

# Normalize embeddings
sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)

#print("Sentence embeddings:")
#print(sentence_embeddings)

# %%
sentence_embeddings.shape
# Out:
# torch.Size([3839, 768])

# %%
data1.shape
# Out:
# (3839, 3)

# %%
data1['Embeddings']=sentence_embeddings.tolist()

# %%
data1.head(3)
# Out:
#   StockCode                         Description  \
# 0    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# 1     71053                 WHITE METAL LANTERN
# 2    84406B      CREAM CUPID HEARTS COAT HANGER
#
#                                              Details  \
# 0  The White Hanging Heart T-Light Holder is a ch...
# 1  A white metal lantern is a decorative accessor...
# 2  The CREAM CUPID HEARTS COAT HANGER is an adora...
#
#                                           Embeddings
# 0  [0.07632849365472794, -0.09431950002908707, -0...
# 1  [0.05321896821260452, -0.03676013648509979, 0....
# 2  [0.03787032142281532, -0.055375922471284866, -...

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
drive_folder_path = '/content/drive/My Drive/Colab Notebooks/'

# %%
data1.to_csv("/content/drive/My Drive/Colab Notebooks/Product_embeddings_Hf.csv")
